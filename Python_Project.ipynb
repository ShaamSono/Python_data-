# %% [markdown]
#  **Import Libraries**

# %%
#Import Libraries
import pandas as pd
# !pip install pyspan
import pyspan as ps
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 50.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Load Dataset**

# %%
#Load Dataset
df = pd.read_csv('/content/hotel_dataset.csv')

# %% [markdown]
# # Perform EDA and Data Cleaning

# %%
#Now Perform EDA and Data Cleaning
df.head()
# Out:
#                         hotel  is_canceled  lead_time  arrival_date_year  \
# 0  \n\n\n Bayat ul Aala Saudi          0.0      342.0             2015.0
# 1  \n\n\n Bayat ul Aala Saudi          0.0      737.0             2015.0
# 2  \n\n\n Bayat ul Aala Saudi          0.0        7.0             2015.0
# 3  \n\n\n Bayat ul Aala Saudi          0.0       13.0             2015.0
# 4  \n\n\n Bayat ul Aala Saudi          0.0       14.0             2015.0
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                      27.0                        1.0
# 1               July                      27.0                        1.0
# 2               July                      27.0                        1.0
# 3               July                      27.0                        1.0
# 4               July                      27.0                        1.0
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type-  \
# ...

# %% [markdown]
# # **how many columns and rows are there**

# %%
#how many columns and rows are there
df.shape
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type-', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119389 non-null  object
#  1   is_canceled                     119389 non-null  float64
#  2   lead_time                       119389 non-null  float64
#  3   arrival_date_year               119387 non-null  float64
#  4   arrival_date_month              119389 non-null  object
#  5   arrival_date_week_number        119389 non-null  float64
#  6   arrival_date_day_of_month       119389 non-null  float64
#  7   stays_in_weekend_nights         119389 non-null  float64
#  8   stays_in_week_nights            119389 non-null  float64
#  9   adults                          119389 non-null  float64
#  10  children                        119385 non-null  float64
# ...

# %%
#DROP DUPLICATE VALUE
df.drop_duplicates(inplace=True)

# %% [markdown]
# # **Drop some Columns**

# %%
#Drop some Columns
df.drop(['name','email','phone-number','credit_card','meal','babies'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'country',
#        'market_segment', 'distribution_channel', 'is_repeated_guest',
#        'previous_cancellations', 'previous_bookings_not_canceled',
#        'reserved_room_type', 'assigned_room_type', 'booking_changes',
#        'deposit_type', 'agent', 'company', 'days_in_waiting_list',
#        'customer_type-', 'adr', 'required_car_parking_spaces',
#        'total_of_special_requests', 'reservation_status',
#        'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119389 non-null  object
#  1   is_canceled                     119389 non-null  float64
#  2   lead_time                       119389 non-null  float64
#  3   arrival_date_year               119387 non-null  float64
#  4   arrival_date_month              119389 non-null  object
#  5   arrival_date_week_number        119389 non-null  float64
#  6   arrival_date_day_of_month       119389 non-null  float64
#  7   stays_in_weekend_nights         119389 non-null  float64
#  8   stays_in_week_nights            119389 non-null  float64
#  9   adults                          119389 non-null  float64
#  10  children                        119385 non-null  float64
# ...

# %% [markdown]
# # **change the data type of reservation_status_date into date data type**

# %%
#change the data type of reservation_status_date into date data type
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119389 non-null  object
#  1   is_canceled                     119389 non-null  float64
#  2   lead_time                       119389 non-null  float64
#  3   arrival_date_year               119387 non-null  float64
#  4   arrival_date_month              119389 non-null  object
#  5   arrival_date_week_number        119389 non-null  float64
#  6   arrival_date_day_of_month       119389 non-null  float64
#  7   stays_in_weekend_nights         119389 non-null  float64
#  8   stays_in_week_nights            119389 non-null  float64
#  9   adults                          119389 non-null  float64
#  10  children                        119385 non-null  float64
# ...

# %%
#now showing the statstics of the objects
df.describe(include='object')
# Out:
#                hotel arrival_date_month country market_segment  \
# count         119389             119389  118900         119387
# unique             2                 12     176              8
# top     Aber ul Arab             August     IND      Online TA
# freq           79330              13877   48741          56476
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119389             119389             119389
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97869              85994              74053
#
#        deposit_type customer_type- reservation_status
# count        119389         119389             119389
# unique            3              4                  3
# top      No Deposit      Transient        Yamanck-Out
# freq         104640          89612              75165

# %% [markdown]
# # **check the missing values**

# %%
df.isnull().sum()
# Out:
# hotel                                  1
# is_canceled                            1
# lead_time                              1
# arrival_date_year                      3
# arrival_date_month                     1
# arrival_date_week_number               1
# arrival_date_day_of_month              1
# stays_in_weekend_nights                1
# stays_in_week_nights                   1
# adults                                 1
# children                               5
# country                              490
# market_segment                         3
# distribution_channel                   1
# is_repeated_guest                      1
# previous_cancellations                 1
# previous_bookings_not_canceled         1
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        1
# deposit_type                           1
# agent                              16341
# company                           112593
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  1
# is_canceled                            1
# lead_time                              1
# arrival_date_year                      3
# arrival_date_month                     1
# arrival_date_week_number               1
# arrival_date_day_of_month              1
# stays_in_weekend_nights                1
# stays_in_week_nights                   1
# adults                                 1
# children                               5
# country                              490
# market_segment                         3
# distribution_channel                   1
# is_repeated_guest                      1
# previous_cancellations                 1
# previous_bookings_not_canceled         1
# reserved_room_type                     1
# assigned_room_type                     1
# booking_changes                        1
# deposit_type                           1
# agent                              16341
# company                           112593
# ...

# %% [markdown]
# # **Summery statsitcs of the numeric columns**

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119389.000000  119389.000000      119387.000000
# mean        0.370419     104.012145        2016.156566
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.482919     106.863248           0.707465
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119389.000000              119389.000000
# mean                  27.165166                  15.798298
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119389 non-null  object
#  1   is_canceled                     119389 non-null  float64
#  2   lead_time                       119389 non-null  float64
#  3   arrival_date_year               119387 non-null  float64
#  4   arrival_date_month              119389 non-null  object
#  5   arrival_date_week_number        119389 non-null  float64
#  6   arrival_date_day_of_month       119389 non-null  float64
#  7   stays_in_weekend_nights         119389 non-null  float64
#  8   stays_in_week_nights            119389 non-null  float64
#  9   adults                          119389 non-null  float64
#  10  children                        119385 non-null  float64
# ...

# %%
df['hotel'].head(20)
# Out:
# 0     \n\n\n Bayat ul Aala Saudi
# 1     \n\n\n Bayat ul Aala Saudi
# 2     \n\n\n Bayat ul Aala Saudi
# 3     \n\n\n Bayat ul Aala Saudi
# 4     \n\n\n Bayat ul Aala Saudi
# 5     \n\n\n Bayat ul Aala Saudi
# 6     \n\n\n Bayat ul Aala Saudi
# 7     \n\n\n Bayat ul Aala Saudi
# 8     \n\n\n Bayat ul Aala Saudi
# 9     \n\n\n Bayat ul Aala Saudi
# 10    \n\n\n Bayat ul Aala Saudi
# 11    \n\n\n Bayat ul Aala Saudi
# 12    \n\n\n Bayat ul Aala Saudi
# 13    \n\n\n Bayat ul Aala Saudi
# 14    \n\n\n Bayat ul Aala Saudi
# 15    \n\n\n Bayat ul Aala Saudi
# 16    \n\n\n Bayat ul Aala Saudi
# 17    \n\n\n Bayat ul Aala Saudi
# 18    \n\n\n Bayat ul Aala Saudi
# 19    \n\n\n Bayat ul Aala Saudi
# Name: hotel, dtype: object

# %% [markdown]
# ### **Use of Pyspan library **

# %% [markdown]
# # **Removing unwanted characters using remove_chars**

# %%
#appling remove_chars function
df = ps.remove_chars(df, columns=['hotel'], custom_characters='n')

# %%
df['hotel'].head(20)
# Out:
# 0     \\\ Bayat ul Aala Saudi
# 1     \\\ Bayat ul Aala Saudi
# 2     \\\ Bayat ul Aala Saudi
# 3     \\\ Bayat ul Aala Saudi
# 4     \\\ Bayat ul Aala Saudi
# 5     \\\ Bayat ul Aala Saudi
# 6     \\\ Bayat ul Aala Saudi
# 7     \\\ Bayat ul Aala Saudi
# 8     \\\ Bayat ul Aala Saudi
# 9     \\\ Bayat ul Aala Saudi
# 10    \\\ Bayat ul Aala Saudi
# 11    \\\ Bayat ul Aala Saudi
# 12    \\\ Bayat ul Aala Saudi
# 13    \\\ Bayat ul Aala Saudi
# 14    \\\ Bayat ul Aala Saudi
# 15    \\\ Bayat ul Aala Saudi
# 16    \\\ Bayat ul Aala Saudi
# 17    \\\ Bayat ul Aala Saudi
# 18    \\\ Bayat ul Aala Saudi
# 19    \\\ Bayat ul Aala Saudi
# Name: hotel, dtype: object

# %%
df = ps.remove_chars(df, columns=['hotel'], custom_characters='\\\ ')

# %%
df['hotel'].head(5)
# Out:
# 0    BayatulAalaSaudi
# 1    BayatulAalaSaudi
# 2    BayatulAalaSaudi
# 3    BayatulAalaSaudi
# 4    BayatulAalaSaudi
# Name: hotel, dtype: object

# %%
member_breakfast = df['country'].value_counts()
member_breakfast.index
# Out:
# Index(['IND', 'Pak', 'Phillipine', 'Egypt', 'Jorden', 'ITA', 'UAE', 'Oman',
#        'BRA', 'NLD',
#        ...
#        'MDG', 'MMR', 'NPL', 'BHS', 'UMI', 'DJI', 'CYM', 'HND', 'VGB', 'NIC'],
#       dtype='object', name='country', length=176)

# %%
df['adr'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Removing Outlier

# %%
 df = df[df['adr'] < 5000]

# %%
cancelled_perc = df['is_canceled'].value_counts(normalize= 1)
print(cancelled_perc)

plt.figure(figsize=(5, 4))
plt.title('Reservation status count')
plt.bar(['Not canceled', 'Canceled'], df['is_canceled'].value_counts(), color=['skyblue', 'gray'])
plt.show()
# Out:
# is_canceled
# 0.0    0.629586
# 1.0    0.370414
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(8 , 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation status in different hotels', fontsize=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.show()

# %%
df['month'] = df['reservation_status_date'].dt.month
plt.figure(figsize=(14, 8))
ax1 = sns.countplot(x='month', hue='is_canceled', data=df, palette='bright')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))
plt.title('Reservation status in different months', fontsize=20)
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.show()

# %%
cancelled_data = df[df['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(20, 8))
plt.title('Top 10 countries with most cancellations')
plt.pie(top_10_country, autopct='%.2f', labels=top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56476
# Offline TA/TO    24217
# Groups           19811
# Direct           12605
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts (normalize = 1 )
# Out:
# market_segment
# Online TA        0.473054
# Offline TA/TO    0.202846
# Groups           0.165941
# Direct           0.105582
# Corporate        0.044352
# Complementary    0.006224
# Aviation         0.001985
# Undefined        0.000017
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=1)
# Out:
# market_segment
# Online TA        0.468964
# Groups           0.273545
# Offline TA/TO    0.187911
# Direct           0.043733
# Corporate        0.022432
# Complementary    0.002193
# Aviation         0.001176
# Undefined        0.000045
# Name: proportion, dtype: float64

# %%
#  find the mean select any column

# Calculate the mean of the 'adr' column
mean_adr = df['adr'].mean()

print(f"The mean of the 'adr' column is: {mean_adr}")
# Out:
# The mean of the 'adr' column is: 101.78656648909438

# %%
# Calculate the median for multiple columns
columns_to_calculate_median = ['lead_time', 'adr', 'stays_in_weekend_nights']
median_values = df[columns_to_calculate_median].median()

print("Median values for selected columns:")
print(median_values)
# Out:
# Median values for selected columns:
# lead_time                  69.00
# adr                        94.56
# stays_in_weekend_nights     1.00
# dtype: float64

# %%
# Calculate the mode for multiple columns
columns_to_calculate_mode = ['hotel', 'market_segment', 'distribution_channel']
mode_values = df[columns_to_calculate_mode].mode().iloc[0]

print("Mode values for selected columns:")
print(mode_values)
# Out:
# Mode values for selected columns:
# hotel                   AberulArab
# market_segment           Online TA
# distribution_channel         TA/TO
# Name: 0, dtype: object
